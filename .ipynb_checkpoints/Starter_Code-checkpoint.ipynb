# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# WARNING:tensorflow:From C:\Users\spizz\anaconda3\envs\dev\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
no_ein_name_df=application_df.drop(columns=["EIN", "NAME"])

# %%
# Determine the number of unique values in each column.
no_ein_name_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_value_counts=no_ein_name_df["APPLICATION_TYPE"].value_counts()

app_value_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff=250
application_types_to_replace=list(app_value_counts[app_value_counts<cutoff].index)


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_value_counts=no_ein_name_df['CLASSIFICATION'].value_counts()
class_value_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
class_greater_one=class_value_counts[class_value_counts>1]
class_greater_one
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff=500
classifications_to_replace=list(class_value_counts[class_value_counts<cutoff].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_dummies_df=pd.get_dummies(no_ein_name_df)

app_dummies_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  \
# 0       1     5000              1                  True                 False
# 1       1   108590              1                 False                 False
# 2       1     5000              0                 False                 False
# 3       1     6692              1                 False                 False
# 4       1   142590              1                 False                 False
#
#    APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  APPLICATION_TYPE_T15  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  INCOME_AMT_1-9999  \
# 0                 False                 False  ...              False
# 1                 False                 False  ...               True
# 2                 False                 False  ...              False
# 3                 False                 False  ...              False
# 4                 False                 False  ...              False
#
#    INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                   False                     False               False
# 1                   False                     False               False
# 2                   False                     False               False
# 3                    True                     False               False
# 4                   False                      True               False
#
#    INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0             False                   False            False
# 1             False                   False            False
# 2             False                   False            False
# 3             False                   False            False
# 4             False                   False            False
#
#    INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0              False                      True                     False
# 1              False                      True                     False
# 2              False                      True                     False
# 3              False                      True                     False
# 4              False                      True                     False
#
# [5 rows x 117 columns]

# %%
# Split our preprocessed data into our features and target arrays
X=app_dummies_df.drop(columns='IS_SUCCESSFUL').values

y=app_dummies_df['IS_SUCCESSFUL'].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

deep_nn_model = tf.keras.models.Sequential()

# First hidden layer
deep_nn_model.add(tf.keras.layers.Dense(units=50, activation="relu", input_dim=len(X_train_scaled[0])))

# Second hidden layer
deep_nn_model.add(tf.keras.layers.Dense(units=25, activation="relu"))


# Output layer
deep_nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Check the structure of the model
deep_nn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 50)                5850
#
#  dense_4 (Dense)             (None, 25)                1275
#
#  dense_5 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 7151 (27.93 KB)
# Trainable params: 7151 (27.93 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
deep_nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = deep_nn_model.fit(X_train_scaled, y_train, epochs=150)
# Out:
# Epoch 1/150
# 804/804 [==============================] - 4s 3ms/step - loss: 0.5762 - accuracy: 0.7208
# Epoch 2/150
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5518 - accuracy: 0.7324
# Epoch 3/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5503 - accuracy: 0.7322
# Epoch 4/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5472 - accuracy: 0.7346
# Epoch 5/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5454 - accuracy: 0.7363
# Epoch 6/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5440 - accuracy: 0.7358
# Epoch 7/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5433 - accuracy: 0.7351
# Epoch 8/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5427 - accuracy: 0.7368
# Epoch 9/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5424 - accuracy: 0.7364
# Epoch 10/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7374
# Epoch 11/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7378
# Epoch 12/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7370
# Epoch 13/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5396 - accuracy: 0.7369
# Epoch 14/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7379
# Epoch 15/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5390 - accuracy: 0.7375
# Epoch 16/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5382 - accuracy: 0.7374
# Epoch 17/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5388 - accuracy: 0.7383
# Epoch 18/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7381
# Epoch 19/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7389
# Epoch 20/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5374 - accuracy: 0.7386
# Epoch 21/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7383
# Epoch 22/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7388
# Epoch 23/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5367 - accuracy: 0.7378
# Epoch 24/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5363 - accuracy: 0.7398
# Epoch 25/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5358 - accuracy: 0.7398
# Epoch 26/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7410
# Epoch 27/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7408
# Epoch 28/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5354 - accuracy: 0.7415
# Epoch 29/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7403
# Epoch 30/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7399
# Epoch 31/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5345 - accuracy: 0.7408
# Epoch 32/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5345 - accuracy: 0.7407
# Epoch 33/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7418
# Epoch 34/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7402
# Epoch 35/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7407
# Epoch 36/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5339 - accuracy: 0.7418
# Epoch 37/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7413
# Epoch 38/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5339 - accuracy: 0.7409
# Epoch 39/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5329 - accuracy: 0.7421
# Epoch 40/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5335 - accuracy: 0.7416
# Epoch 41/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7420
# Epoch 42/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7418
# Epoch 43/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7410
# Epoch 44/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5328 - accuracy: 0.7414
# Epoch 45/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7413
# Epoch 46/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7423
# Epoch 47/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5325 - accuracy: 0.7420
# Epoch 48/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5321 - accuracy: 0.7429
# Epoch 49/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7429
# Epoch 50/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5322 - accuracy: 0.7424
# Epoch 51/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5321 - accuracy: 0.7418
# Epoch 52/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5319 - accuracy: 0.7427
# Epoch 53/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7432
# Epoch 54/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5312 - accuracy: 0.7422
# Epoch 55/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5318 - accuracy: 0.7416
# Epoch 56/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5313 - accuracy: 0.7414
# Epoch 57/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7420
# Epoch 58/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7425
# Epoch 59/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7435
# Epoch 60/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5312 - accuracy: 0.7426
# Epoch 61/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7444
# Epoch 62/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5306 - accuracy: 0.7432
# Epoch 63/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5304 - accuracy: 0.7437
# Epoch 64/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7430
# Epoch 65/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7426
# Epoch 66/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7426
# Epoch 67/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5303 - accuracy: 0.7431
# Epoch 68/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5299 - accuracy: 0.7427
# Epoch 69/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7423
# Epoch 70/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5303 - accuracy: 0.7423
# Epoch 71/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5300 - accuracy: 0.7428
# Epoch 72/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7430
# Epoch 73/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5295 - accuracy: 0.7442
# Epoch 74/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5300 - accuracy: 0.7428
# Epoch 75/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5297 - accuracy: 0.7434
# Epoch 76/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5297 - accuracy: 0.7431
# Epoch 77/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5294 - accuracy: 0.7433
# Epoch 78/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5294 - accuracy: 0.7437
# Epoch 79/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5293 - accuracy: 0.7441
# Epoch 80/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5297 - accuracy: 0.7439
# Epoch 81/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5290 - accuracy: 0.7442
# Epoch 82/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5289 - accuracy: 0.7442
# Epoch 83/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5291 - accuracy: 0.7430
# Epoch 84/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5289 - accuracy: 0.7439
# Epoch 85/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5288 - accuracy: 0.7433
# Epoch 86/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5293 - accuracy: 0.7444
# Epoch 87/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5287 - accuracy: 0.7438
# Epoch 88/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5288 - accuracy: 0.7432
# Epoch 89/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5289 - accuracy: 0.7424
# Epoch 90/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5285 - accuracy: 0.7446
# Epoch 91/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5291 - accuracy: 0.7437
# Epoch 92/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5288 - accuracy: 0.7442
# Epoch 93/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5286 - accuracy: 0.7432
# Epoch 94/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5286 - accuracy: 0.7445
# Epoch 95/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5282 - accuracy: 0.7442
# Epoch 96/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5285 - accuracy: 0.7441
# Epoch 97/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5281 - accuracy: 0.7449
# Epoch 98/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5281 - accuracy: 0.7445
# Epoch 99/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5281 - accuracy: 0.7448
# Epoch 100/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5280 - accuracy: 0.7444
# Epoch 101/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5281 - accuracy: 0.7440
# Epoch 102/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5280 - accuracy: 0.7430
# Epoch 103/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5281 - accuracy: 0.7442
# Epoch 104/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5279 - accuracy: 0.7438
# Epoch 105/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5280 - accuracy: 0.7449
# Epoch 106/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5280 - accuracy: 0.7442
# Epoch 107/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5278 - accuracy: 0.7443
# Epoch 108/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5276 - accuracy: 0.7442
# Epoch 109/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5278 - accuracy: 0.7442
# Epoch 110/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5274 - accuracy: 0.7447
# Epoch 111/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5276 - accuracy: 0.7435
# Epoch 112/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5276 - accuracy: 0.7447
# Epoch 113/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5277 - accuracy: 0.7441
# Epoch 114/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5274 - accuracy: 0.7436
# Epoch 115/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5272 - accuracy: 0.7444
# Epoch 116/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5271 - accuracy: 0.7438
# Epoch 117/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5275 - accuracy: 0.7442
# Epoch 118/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5271 - accuracy: 0.7444
# Epoch 119/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5272 - accuracy: 0.7443
# Epoch 120/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5271 - accuracy: 0.7444
# Epoch 121/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5274 - accuracy: 0.7438
# Epoch 122/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5267 - accuracy: 0.7444
# Epoch 123/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5268 - accuracy: 0.7439
# Epoch 124/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5272 - accuracy: 0.7446
# Epoch 125/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5270 - accuracy: 0.7455
# Epoch 126/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5271 - accuracy: 0.7441
# Epoch 127/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5266 - accuracy: 0.7435
# Epoch 128/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5265 - accuracy: 0.7458
# Epoch 129/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5267 - accuracy: 0.7440
# Epoch 130/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5279 - accuracy: 0.7451
# Epoch 131/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5269 - accuracy: 0.7451
# Epoch 132/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5268 - accuracy: 0.7444
# Epoch 133/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5264 - accuracy: 0.7451
# Epoch 134/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5268 - accuracy: 0.7445
# Epoch 135/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5263 - accuracy: 0.7447
# Epoch 136/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5261 - accuracy: 0.7449
# Epoch 137/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5265 - accuracy: 0.7445
# Epoch 138/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5266 - accuracy: 0.7451
# Epoch 139/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5262 - accuracy: 0.7443
# Epoch 140/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5263 - accuracy: 0.7447
# Epoch 141/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5261 - accuracy: 0.7454
# Epoch 142/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5260 - accuracy: 0.7448
# Epoch 143/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5265 - accuracy: 0.7455
# Epoch 144/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5266 - accuracy: 0.7448
# Epoch 145/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5263 - accuracy: 0.7449
# Epoch 146/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5266 - accuracy: 0.7442
# Epoch 147/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5263 - accuracy: 0.7443
# Epoch 148/150
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5262 - accuracy: 0.7444
# Epoch 149/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5269 - accuracy: 0.7441
# Epoch 150/150
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5260 - accuracy: 0.7448

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = deep_nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5601 - accuracy: 0.7263 - 1s/epoch - 4ms/step
# Loss: 0.5600693225860596, Accuracy: 0.7262973785400391

# %%
# Export our model to HDF5 file
deep_nn_model.save("deep_nn_model.h5")
# Out:
# C:\Users\spizz\anaconda3\envs\dev\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
